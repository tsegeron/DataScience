# %%
import pandas as pd

# %%
df = pd.read_json('auto.json')
df
# Out:
#         CarNumber  Refund         Fines    Make    Model
# 0    Y163O8161RUS       2   3200.000000    Ford    Focus
# 1     E432XX77RUS       1   6500.000000  Toyota    Camry
# 2     7184TT36RUS       1   2100.000000    Ford    Focus
# 3    X582HE161RUS       2   2000.000000    Ford    Focus
# 4    92918M178RUS       1   5700.000000    Ford    Focus
# ..            ...     ...           ...     ...      ...
# 720  Y163O8161RUS       2   1600.000000    Ford    Focus
# 721  M0309X197RUS       1  22300.000000    Ford    Focus
# 722  O673E8197RUS       2    600.000000    Ford    Focus
# 723  8610T8154RUS       1   2000.000000    Ford    Focus
# 724  H419XE197RUS       2   8594.586466  Toyota  Corolla
#
# [725 rows x 5 columns]

# %%
df.set_index('CarNumber', inplace=True)
df.head()
# Out:
#               Refund   Fines    Make  Model
# CarNumber
# Y163O8161RUS       2  3200.0    Ford  Focus
# E432XX77RUS        1  6500.0  Toyota  Camry
# 7184TT36RUS        1  2100.0    Ford  Focus
# X582HE161RUS       2  2000.0    Ford  Focus
# 92918M178RUS       1  5700.0    Ford  Focus

# %%
df[df.Fines > 2100]
# Out:
#               Refund         Fines        Make    Model
# CarNumber
# Y163O8161RUS       2   3200.000000        Ford    Focus
# E432XX77RUS        1   6500.000000      Toyota    Camry
# 92918M178RUS       1   5700.000000        Ford    Focus
# H234YH197RUS       2   6000.000000        Ford    Focus
# E40577152RUS       1   8594.586466        Ford    Focus
# ...              ...           ...         ...      ...
# O718MM163RUS       2   8594.586466        Ford    Focus
# 7065C8197RUS       2  11400.000000  Volkswagen   Passat
# O22097197RUS       1  24300.000000        Ford    Focus
# M0309X197RUS       1  22300.000000        Ford    Focus
# H419XE197RUS       2   8594.586466      Toyota  Corolla
#
# [455 rows x 4 columns]

# %%
df[(df.Fines > 2100) & (df.Refund == 2)]
# Out:
#               Refund         Fines        Make    Model
# CarNumber
# Y163O8161RUS       2   3200.000000        Ford    Focus
# H234YH197RUS       2   6000.000000        Ford    Focus
# 707987163RUS       2   2200.000000        Ford    Focus
# K330T8197RUS       2   8200.000000       Skoda  Octavia
# M592CH197RUS       2   8594.586466       Skoda  Octavia
# ...              ...           ...         ...      ...
# O136HO197RUS       2   7800.000000      Toyota  Corolla
# O68897197RUS       2  12300.000000        Ford    Focus
# O718MM163RUS       2   8594.586466        Ford    Focus
# 7065C8197RUS       2  11400.000000  Volkswagen   Passat
# H419XE197RUS       2   8594.586466      Toyota  Corolla
#
# [309 rows x 4 columns]

# %%
df[df.Model.isin(['Focus', 'Corolla'])]
# Out:
#               Refund         Fines    Make    Model
# CarNumber
# Y163O8161RUS       2   3200.000000    Ford    Focus
# 7184TT36RUS        1   2100.000000    Ford    Focus
# X582HE161RUS       2   2000.000000    Ford    Focus
# 92918M178RUS       1   5700.000000    Ford    Focus
# H234YH197RUS       2   6000.000000    Ford    Focus
# ...              ...           ...     ...      ...
# Y163O8161RUS       2   1600.000000    Ford    Focus
# M0309X197RUS       1  22300.000000    Ford    Focus
# O673E8197RUS       2    600.000000    Ford    Focus
# 8610T8154RUS       1   2000.000000    Ford    Focus
# H419XE197RUS       2   8594.586466  Toyota  Corolla
#
# [593 rows x 4 columns]

# %%
df[df.index.isin(['Y7689C197RUS', '92928M178RUS', '7788KT197RUS', 'H115YO163RUS', 'X758HY197RUS'])]
# Out:
#               Refund          Fines  Make  Model
# CarNumber
# 92928M178RUS       1    8594.586466  Ford  Focus
# H115YO163RUS       1    2200.000000  Ford  Focus
# 7788KT197RUS       2   12000.000000  Ford  Focus
# X758HY197RUS       2   24200.000000  Ford  Focus
# X758HY197RUS       2   72600.000000  Ford  Focus
# Y7689C197RUS       1   27000.000000  Ford  Focus
# 92928M178RUS       1     600.000000  Ford  Focus
# H115YO163RUS       1    8594.586466  Ford  Focus
# H115YO163RUS       2    1100.000000  Ford  Focus
# 7788KT197RUS       2    8594.586466  Ford  Focus
# 7788KT197RUS       1   20000.000000  Ford  Focus
# X758HY197RUS       2  145200.000000  Ford  Focus
# 92928M178RUS       1    1200.000000  Ford  Focus
# Y7689C197RUS       2    9000.000000  Ford  Focus
# Y7689C197RUS       2   45000.000000  Ford  Focus
# 7788KT197RUS       2    4000.000000  Ford  Focus
# Y7689C197RUS       1   36000.000000  Ford  Focus
# 92928M178RUS       2    3000.000000  Ford  Focus

# %% [markdown]
# ## Make the aggregations with the make and the model

# %%
df.groupby('Make')['Fines'].median()
# Out:
# Make
# Audi          4200.0
# BMW           6500.0
# Ford          3500.0
# Skoda         3250.0
# Toyota        7700.0
# Volkswagen    4300.0
# Volvo         8500.0
# Name: Fines, dtype: float64

# %%
df.groupby(['Make', 'Model'])['Fines'].median()
# Out:
# Make        Model
# Ford        Focus      3500.0
#             Mondeo     7650.0
# Skoda       Octavia    3250.0
# Toyota      Camry      7700.0
#             Corolla    7700.0
# Volkswagen  Golf       4800.0
#             Jetta      2800.0
#             Passat     3500.0
#             Touareg    5800.0
# Name: Fines, dtype: float64

# %%
df.groupby(['Make', 'Model'])['Fines'].count()
# Out:
# Make        Model
# Ford        Focus      575
#             Mondeo       6
# Skoda       Octavia     48
# Toyota      Camry       16
#             Corolla     18
# Volkswagen  Golf        20
#             Jetta        6
#             Passat      22
#             Touareg      5
# Name: Fines, dtype: int64

# %%
df.groupby(['Make', 'Model'])['Fines'].describe()
# Out:
#                     count          mean           std     min     25%     50%  \
# Make       Model
# Ford       Focus    575.0   8184.445897  15041.269437   100.0  1200.0  3500.0
#            Mondeo     6.0  16533.333333  18987.329108  1100.0  3325.0  7650.0
# Skoda      Octavia   48.0   9399.835526  23070.518968   300.0  1275.0  3250.0
# Toyota     Camry     16.0   8236.823308   6410.250654   500.0  3550.0  7700.0
#            Corolla   18.0  10583.032581   9629.325617   900.0  4100.0  7700.0
# Volkswagen Golf      20.0  15744.729323  36950.839950   200.0   450.0  4800.0
#            Jetta      6.0  10350.000000  17743.026799   500.0  1150.0  2800.0
#            Passat    22.0   6363.144224   6969.739135   100.0  1150.0  3500.0
#            Touareg    5.0   4498.917293   3461.778173   500.0  1300.0  5800.0
#
#                              75%            max
# Make       Model
# Ford       Focus     8594.586466  180000.000000
#            Mondeo   27950.000000   46200.000000
# ...

# %% [markdown]
# ## Make the aggregations with the car number

# %%
df.groupby(df.index)['Fines'].count().sort_values(ascending=False)
# Out:
# CarNumber
# Y7689C197RUS    4
# 92928M178RUS    4
# 7788KT197RUS    4
# H115YO163RUS    3
# X758HY197RUS    3
#                ..
# E42577152RUS    1
# E42377152RUS    1
# E41977152RUS    1
# E41577152RUS    1
# H917TC36RUS     1
# Name: Fines, Length: 531, dtype: int64

# %%
df[df.index == 'Y7689C197RUS']
# Out:
#               Refund    Fines  Make  Model
# CarNumber
# Y7689C197RUS       1  27000.0  Ford  Focus
# Y7689C197RUS       2   9000.0  Ford  Focus
# Y7689C197RUS       2  45000.0  Ford  Focus
# Y7689C197RUS       1  36000.0  Ford  Focus

# %%
df.groupby(df.index)['Fines'].sum().sort_values(ascending=False)
# Out:
# CarNumber
# X758HY197RUS    242000.0
# 9020YC197RUS    217500.0
# M0279X197RUS    216000.0
# Y352O8197RUS    207200.0
# Y778EE197RUS    192000.0
#                   ...
# 83218C154RUS       100.0
# Y195O8161RUS       100.0
# K376HE161RUS       100.0
# 705787163RUS       100.0
# K326T8197RUS       100.0
# Name: Fines, Length: 531, dtype: float64

# %%
df[df.index == 'X758HY197RUS']
# Out:
#               Refund     Fines  Make  Model
# CarNumber
# X758HY197RUS       2   24200.0  Ford  Focus
# X758HY197RUS       2   72600.0  Ford  Focus
# X758HY197RUS       2  145200.0  Ford  Focus

# %%
df_dif_mod = df.reset_index().drop_duplicates(['CarNumber', 'Make', 'Model'])
df_dif_mod
# Out:
#         CarNumber  Refund    Fines    Make    Model
# 0    Y163O8161RUS       2   3200.0    Ford    Focus
# 1     E432XX77RUS       1   6500.0  Toyota    Camry
# 2     7184TT36RUS       1   2100.0    Ford    Focus
# 3    X582HE161RUS       2   2000.0    Ford    Focus
# 4    92918M178RUS       1   5700.0    Ford    Focus
# ..            ...     ...      ...     ...      ...
# 715  O136HO197RUS       2   7800.0  Toyota  Corolla
# 719  O22097197RUS       1  24300.0    Ford    Focus
# 721  M0309X197RUS       1  22300.0    Ford    Focus
# 722  O673E8197RUS       2    600.0    Ford    Focus
# 723  8610T8154RUS       1   2000.0    Ford    Focus
#
# [532 rows x 5 columns]

# %%
df_dif_mod.groupby('CarNumber')['Make'].count().sort_values(ascending=False)
# Out:
# CarNumber
# E316EH197RUS    2
# 704687163RUS    1
# O64297197RUS    1
# O481OH77RUS     1
# O49797197RUS    1
#                ..
# C299K9154RUS    1
# 9975CC77RUS     1
# 9943OH154RUS    1
# 9943KK197RUS    1
# Y973O8197RUS    1
# Name: Make, Length: 531, dtype: int64

# %%
df_dif_mod[df_dif_mod.CarNumber == 'E316EH197RUS']
# Out:
#         CarNumber  Refund   Fines        Make    Model
# 157  E316EH197RUS       1  1300.0  Volkswagen     None
# 429  E316EH197RUS       1  1300.0  Volkswagen  Touareg
